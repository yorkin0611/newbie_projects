# %% [markdown]
# # TASK #1. GUIDED PROJECT INTRODUCTION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2. DEFINE A PANDAS SERIES

# %%
# Pandas is a data manipulation and analysis tool that is built on Numpy.
# Pandas uses a data structure known as DataFrame (think of it as Microsoft excel in Python).
# DataFrames empower programmers to store and manipulate data in a tabular fashion (rows and columns).
# Series Vs. DataFrame? Series is considered a single column of a DataFrame.

import pandas as pd

# %%
# Let's define a Python list that contains 5 crypto currencies
crypto_list = ['BTC', 'XRP', 'LTC', 'ADA', 'ETH']

# %%
# Let's confirm the Datatype
type(crypto_list)
# Out:
# list

# %%
# Let's create a one dimensional Pandas "series"
# Let's use Pandas Constructor Method to create a series from a Python list
# Note that series is formed of data and associated index (numeric index has been automatically generated)
# Check Pandas Documentation for More information: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html#pandas.Series
# Object datatype is used for text data (String)
crypto_series = pd.Series(crypto_list)
crypto_series
# Out:
# 0    BTC
# 1    XRP
# 2    LTC
# 3    ADA
# 4    ETH
# dtype: object

# %%
# Let's confirm the Pandas Series Datatype
type(crypto_series)
# Out:
# pandas.core.series.Series

# %%
# Let's define another Pandas Series that contains numeric values (crypto prices) instead of text data
# Note that we have int64 datatype which means it's integer stored in 64 bits in memory
crypto_prices = pd.Series(data=[473, 5492, 2983, 111, 50])
crypto_prices
# Out:
# 0     473
# 1    5492
# 2    2983
# 3     111
# 4      50
# dtype: int64

# %% [markdown]
# # PRACTICE OPPORTUNITY #1 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_list = ['Podravka', 'CroCube', 'Tesla Ericsson']
my_series = pd.Series(data=my_list)
my_series
# Out:
# 0          Podravka
# 1           CroCube
# 2    Tesla Ericsson
# dtype: object

# %%
type(my_series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # TASK #3. DEFINE A PANDAS SERIES WITH CUSTOM INDEX

# %%
# Let's define a Python list that contains 5 Crypto currencies
crypto_list = ['BTC', 'XRP', 'LTC', 'ADA', 'ETH']

# %%
# Let's define a python list as shown below. This python list will be used for the Series index:
crypto_labels = ['crypto#1', 'crypto#2', 'crypto#3', 'crypto#4', 'crypto#5']

# %%
# Let's create a one dimensional Pandas "series"
# Let's use Pandas Constructor Method to create a series from a Python list
# Note that this series is formed of data and associated labels
new_crypto = pd.Series(index=crypto_labels, data=crypto_list)

# %%
# Let's view the series
new_crypto
# Out:
# crypto#1    BTC
# crypto#2    XRP
# crypto#3    LTC
# crypto#4    ADA
# crypto#5    ETH
# dtype: object

# %%
# Let's obtain the datatype
type(new_crypto)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # TASK #4. DEFINE A PANDAS SERIES FROM A DICTIONARY

# %%
# A Dictionary consists of a collection of key-value pairs. Each key-value pair maps the key to its corresponding value.
# Keys are unique within a dictionary while values may not be.
# List elements are accessed by their position in the list, via indexing while Dictionary elements are accessed via keys
# Define a dictionary named "my_dict" using key-value pairs
my_dict = {'Employee ID': 3,
 'Employee Name': 'John',
 'Salary [$]': 1750,
 'Years with company': 3}

# %%
# Show the dictionary
my_dict
# Out:
# {'Employee ID': 3,
#  'Employee Name': 'John',
#  'Salary [$]': 1750,
#  'Years with company': 3}

# %%
# Confirm the dictionary datatype
type(my_dict)
# Out:
# dict

# %%
# Let's define a Pandas Series Using the dictionary
employee_series = pd.Series(data=my_dict)
employee_series
# Out:
# Employee ID              3
# Employee Name         John
# Salary [$]            1750
# Years with company       3
# dtype: object

# %% [markdown]
# # PRACTICE OPPORTUNITY #2 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
new_dict= {'Podravka': 5000, 'CroCube': 3419, 'Tesla Ericsson': 871}
new_stocks = pd.Series(data=new_dict)
new_stocks
# Out:
# Podravka          5000
# CroCube           3419
# Tesla Ericsson     871
# dtype: int64

# %% [markdown]
# # TASK #5. PANDAS ATTRIBUTES

# %%
# Attributes/Properties: do not use parantheses "()" and are used to get Pandas Series Properties. Ex: my_series.values, my_series.shape
# Methods: use parantheses "()" and might include arguments and they actually alter/change the Pandas Series. Ex: my_series.tail(), my_series.head(), my_series.drop_duplicates()
# Indexers: use square brackets "[]" and are used to access specific elements in a Pandas Series or DataFrame. Ex: my_series.loc[], my_series.iloc[]

# Let's redefine a Pandas Series containing our favourite 5 cryptos
crypto_list = ['BTC', 'XRP', 'LTC', 'ADA', 'ETH']
crypto_series = pd.Series(crypto_list)
crypto_series
# Out:
# 0    BTC
# 1    XRP
# 2    LTC
# 3    ADA
# 4    ETH
# dtype: object

# %%
# ".Values" attribute is used to return Series as ndarray depending on its dtype
# Check this for more information: https://pandas.pydata.org/docs/reference/api/pandas.Series.values.html#pandas.Series.values
crypto_series.values
# Out:
# array(['BTC', 'XRP', 'LTC', 'ADA', 'ETH'], dtype=object)

# %%
# index is used to return the index (axis labels) of the Series
crypto_series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# dtype is used to return the datatype of the Series ('O' stands for 'object' datatype)
crypto_series.dtype
# Out:
# dtype('O')

# %%
# Check if all elements are unique or not
crypto_series.is_unique
# Out:
# True

# %%
# Check the shape of the Series
# note that a Series is one dimensional
crypto_series.shape
# Out:
# (5,)

# %% [markdown]
# # TASK #6. PANDAS METHODS

# %%
# Methods have parentheses and they actually alter/change the Pandas Series
# Methods: use parantheses "()" and might include arguments. Ex: my_series.tail(), my_series.head(), my_series.drop_duplicates()

# Let's define another Pandas Series that contains numeric values (crypto prices) instead of text data
# Note that we have int64 datatype which means it contains integer values stored in 64 bits in memory
crypto_prices = pd.Series(data=[473, 5492, 2983, 111, 50])
crypto_prices
# Out:
# 0     473
# 1    5492
# 2    2983
# 3     111
# 4      50
# dtype: int64

# %%
# Let's obtain the sum of all elements in the Pandas Series
crypto_prices.sum()
# Out:
# 9109

# %%
# Let's obtain the multiplication of all elements in the Pandas Series
crypto_prices.product()
# Out:
# 43006876895400

# %%
# Let's obtain the average
crypto_prices.mean()
# Out:
# 1821.8

# %%
# Let's show the first couple of elements in the Pandas Series
crypto_prices.head(2)
# Out:
# 0     473
# 1    5492
# dtype: int64

# %%
# Note that head creates a new dataframe
subset = crypto_prices.head(3)
subset
# Out:
# 0     473
# 1    5492
# 2    2983
# dtype: int64

# %% [markdown]
# # PRACTICE OPPORTUNITY #3 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
crypto_prices.tail(2)
# Out:
# 3    111
# 4     50
# dtype: int64

# %%
crypto_prices.memory_usage()
# Out:
# 168

# %% [markdown]
# # TASK #7. IMPORT CSV DATA (1-D) USING PANDAS

# %%
# Pandas read_csv is used to read a csv file and store data in a DataFrame by default (DataFrames will be covered shortly!)
# Use Squeeze to convert it into a Pandas Series (One-dimensional)
# Notice that no foramtting exists when a Series is plotted
series_csv = pd.read_csv("crypto.csv").squeeze()
series_csv
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
series_csv = pd.read_csv("crypto.csv")
series_csv
# Out:
#       BTC-USD Price
# 0        457.334015
# 1        424.440002
# 2        394.795990
# 3        408.903992
# 4        398.821014
# ...             ...
# 2380   55950.746090
# 2381   57750.199220
# 2382   58917.691410
# 2383   58918.832030
# 2384   59095.808590
#
# [2385 rows x 1 columns]

# %%
# Note that when you set Squeeze = False, the data is stored in a DataFrame by default.
# DataFrame is simply used to store multi dimensional data as compares to Pandas Series that only holds 1-D dataset
# Note that DataFrames has proper formatting when you attempt to view them as shown below
# Note that Pandas Series has no formatting

# %%
type(series_csv)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # TASK #8. PANDAS BUILT-IN FUNCTIONS

# %%
# Pandas works great with pre-existing python functions
# You don't have to play with pandas methods and directly leverage Python functions
# Check Python built-in functions here: https://docs.python.org/3/library/functions.html
series_csv = pd.read_csv("crypto.csv").squeeze()
series_csv.head()
# Out:
# 0    457.334015
# 1    424.440002
# 2    394.795990
# 3    408.903992
# 4    398.821014
# Name: BTC-USD Price, dtype: float64

# %%
# Obtain the Data Type of the Pandas Series
type(series_csv)
# Out:
# pandas.core.series.Series

# %%
# Obtain the length of the Pandas Series
series_csv.size
#len(series_csv)
# Out:
# 2385

# %%
# Obtain the maximum value of the Pandas Series
series_csv.max()
# Out:
# 61243.08594

# %%
# Obtain the minimum value of the Pandas Series
series_csv.min()
# Out:
# 178.1029968

# %% [markdown]
# # PRACTICE OPPORTUNITY #4 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_series=pd.Series(data=[-10,100,-30,50,100])
my_series.abs()
# Out:
# 0     10
# 1    100
# 2     30
# 3     50
# 4    100
# dtype: int64

# %%
my_series.drop_duplicates()
# Out:
# 0    -10
# 1    100
# 2    -30
# 3     50
# dtype: int64

# %% [markdown]
# # TASK #9. SORTING PANDAS SERIES

# %%
# Let's import CSV data as follows:
series_csv = pd.read_csv("crypto.csv").squeeze()
series_csv
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# You can sort the values in the dataframe as follows
series_csv.sort_values()
# Out:
# 119       178.102997
# 122       199.259995
# 121       208.097000
# 120       209.843994
# 123       210.339004
#             ...
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# 2366    59302.316410
# 2365    61243.085940
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Let's view Pandas Series again after sorting, Note that nothing changed in memory! you have to make sure that inplace is set to True
series_csv
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Set inplace = True to ensure that change has taken place in memory
series_csv.sort_values(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-456188533f56> in <cell line: 2>()
#       1 # Set inplace = True to ensure that change has taken place in memory
# ----> 2 series_csv.sort_values(inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3612         # GH 5856/5853
#    3613         if inplace and self._is_cached:
# -> 3614             raise ValueError(
#    3615                 "This Series is a view of some other array, to "
#    3616                 "sort in-place you must create a copy"
#
# ValueError: This Series is a view of some other array, to sort in-place you must create a copy

# %%
# Note that now the change (ordering) took place
series_csv

# %%
# Notice that the indexes are now changed
# You can also sort by index (revert back to the original Pandas Series) as follows:
series_csv.sort_index(inplace=True)
series_csv
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
series_csv.sort_values(ascending=False, inplace=True)
series_csv
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-35e107a498d6> in <cell line: 1>()
# ----> 1 series_csv.sort_values(ascending=False, inplace=True)
#       2 series_csv
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3612         # GH 5856/5853
#    3613         if inplace and self._is_cached:
# -> 3614             raise ValueError(
#    3615                 "This Series is a view of some other array, to "
#    3616                 "sort in-place you must create a copy"
#
# ValueError: This Series is a view of some other array, to sort in-place you must create a copy

# %% [markdown]
# # TASK #10. PERFORM MATH OPERATIONS ON PANDAS SERIES

# %%
# Let's import CSV data as follows:
series_csv = pd.read_csv("crypto.csv").squeeze()
series_csv
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Apply Sum Method on Pandas Series
series_csv.sum()
# Out:
# 15435379.738852698

# %%
# Apply count Method on Pandas Series
series_csv.count()
# Out:
# 2385

# %%
# Obtain the maximum value
series_csv.max()
# Out:
# 61243.08594

# %%
# Obtain the minimum value
series_csv.min()
# Out:
# 178.1029968

# %%
# My favourite: Describe!
# Describe is used to obtain all statistical information in one place
series_csv.describe()
# Out:
# count     2385.000000
# mean      6471.857333
# std       9289.022505
# min        178.102997
# 25%        454.618988
# 50%       4076.632568
# 75%       8864.766602
# max      61243.085940
# Name: BTC-USD Price, dtype: float64

# %% [markdown]
# # PRACTICE OPPORTUNITY #5 [OPTIONAL]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
series_csv.mean()
# Out:
# 6471.857332852284

# %%
series_csv.sum()/series_csv.count()
# Out:
# 6471.857332852284

# %% [markdown]
# # TASK #11. CHECK IF A GIVEN ELEMENT EXISTS IN A PANDAS SERIES

# %%
# Let's import CSV data as follows:
series_csv = pd.read_csv("crypto.csv").squeeze()
series_csv
# Out:
# 0         457.334015
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
#             ...
# 2380    55950.746090
# 2381    57750.199220
# 2382    58917.691410
# 2383    58918.832030
# 2384    59095.808590
# Name: BTC-USD Price, Length: 2385, dtype: float64

# %%
# Check if a given number exists in a Pandas Series values
# Returns a boolean "True" or "False"
1295.50 in series_csv.values
# Out:
# False

# %%
# Check if a given number exists in a Pandas Series index
1295.00 in series_csv.index
# Out:
# True

# %%
# Note that by default 'in' will search in Pandas index and not values
1295 in series_csv
# Out:
# True

# %% [markdown]
# # CAPSTONE FINAL PROJECT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # CAPSTONE FINAL PROJECT SOLUTION

# %% [markdown]
# # PART A

# %%
# Import key libraries
import pandas as pd
import numpy as np

# %%
# Define a portfolio dictionary containing 3 stocks and 3 crypto
portfolio = {'BTC':  67873.59,
             'ETH':  3381.88,
             'ADA':  0.590700,
             'AAPL': 171.49,
             'TSLA': 176.09,
             'AMZN': 184.54}
print(portfolio)
# Out:
# {'BTC': 67873.59, 'ETH': 3381.88, 'ADA': 0.5907, 'AAPL': 171.49, 'TSLA': 176.09, 'AMZN': 184.54}

# %%
# Define a Pandas Series Using the dictionary
my_portfolio_series = pd.Series(portfolio)
my_portfolio_series
# Out:
# BTC     67873.5900
# ETH      3381.8800
# ADA         0.5907
# AAPL      171.4900
# TSLA      176.0900
# AMZN      184.5400
# dtype: float64

# %%
# Define another Pandas series containing the number of securities
number_securities = pd.Series(data = [3, 10, 1000, 5, 20, 20],  index = ['BTC', 'ETH', 'ADA', 'AAPL', 'TSLA', 'AMZN'])
number_securities
# Out:
# BTC        3
# ETH       10
# ADA     1000
# AAPL       5
# TSLA      20
# AMZN      20
# dtype: int64

# %%
# Multiply Pandas Series instances
Total_dollar_value = my_portfolio_series.mul(number_securities);
print(Total_dollar_value)
# Out:
# BTC     203620.77
# ETH      33818.80
# ADA        590.70
# AAPL       857.45
# TSLA      3521.80
# AMZN      3690.80
# dtype: float64

# %%
print(f'Total portfolio Value = {(Total_dollar_value.sum())}')
# Out:
# Total portfolio Value = 246100.32

# %% [markdown]
# # PART B

# %%
# Pandas read_csv is used to read a csv file and store data in a DataFrame by default (DataFrames will be covered shortly!)
# Use Squeeze to convert it into a Pandas Series (One-dimensional)
# Notice that no foramtting exists when a Series is plotted
sp500 = pd.read_csv('S&P500_Prices.csv')
sp500.head(5)
# Out:
#          sp500
# 0  1295.500000
# 1  1289.089966
# 2  1293.670044
# 3  1308.040039
# 4  1314.500000

# %%
# Pandas read_csv is used to read a csv file and store data in a DataFrame by default (DataFrames will be covered shortly!)
# Use Squeeze to convert it into a Pandas Series (One-dimensional)
# Notice that no foramtting exists when a Series is plotted
sp500 = pd.read_csv('S&P500_Prices.csv').squeeze()
sp500.head(5)
# Out:
# 0    1295.500000
# 1    1289.089966
# 2    1293.670044
# 3    1308.040039
# 4    1314.500000
# Name: sp500, dtype: float64

# %%
# Obtain the Data Type of the Pandas Series
type(sp500)
# Out:
# pandas.core.series.Series

# %%
# Obtain the length of the Pandas Series
len(sp500)
# Out:
# 2159

# %%
# Obtain the maximum value of the Pandas Series
sp500.max()
# Out:
# 3386.149902

# %%
# Obtain the minimum value of the Pandas Series
sp500.min()
# Out:
# 1278.040039

# %%
# Set inplace = True to ensure that change has taken place in memory
sp500.sort_values(inplace = True)
sp500
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-05f19e500b2f> in <cell line: 2>()
#       1 # Set inplace = True to ensure that change has taken place in memory
# ----> 2 sp500.sort_values(inplace = True)
#       3 sp500
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3612         # GH 5856/5853
#    3613         if inplace and self._is_cached:
# -> 3614             raise ValueError(
#    3615                 "This Series is a view of some other array, to "
#    3616                 "sort in-place you must create a copy"
#
# ValueError: This Series is a view of some other array, to sort in-place you must create a copy

# %%
# Notice that the indexes are now changed
# You can also sort by index (revert back to the original Pandas Series) as follows:
sp500.sort_index(inplace = True)
sp500
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
sp500.sort_values(ascending = False, inplace = True)
sp500
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-9bf3e33215aa> in <cell line: 1>()
# ----> 1 sp500.sort_values(ascending = False, inplace = True)
#       2 sp500
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3612         # GH 5856/5853
#    3613         if inplace and self._is_cached:
# -> 3614             raise ValueError(
#    3615                 "This Series is a view of some other array, to "
#    3616                 "sort in-place you must create a copy"
#
# ValueError: This Series is a view of some other array, to sort in-place you must create a copy

# %%
# Obtain the average - Solution #1
print(sp500.sum()/sp500.count())

# Obtain the average - Solution #s
print(sp500.mean())
# Out:
# 2218.7495540592868
# 2218.7495540592868

# %%
# My favourite: Describe!
# Describe is used to obtain all statistical information in one place
sp500.describe()
# Out:
# count    2159.000000
# mean     2218.749554
# std       537.321727
# min      1278.040039
# 25%      1847.984985
# 50%      2106.629883
# 75%      2705.810059
# max      3386.149902
# Name: sp500, dtype: float64

# %%
3349 in sp500.values
# Out:
# False

# %%
sp500 = round(sp500)
sp500
# Out:
# 0       1296.0
# 1       1289.0
# 2       1294.0
# 3       1308.0
# 4       1314.0
#          ...
# 2154    3328.0
# 2155    3349.0
# 2156    3351.0
# 2157    3360.0
# 2158    3334.0
# Name: sp500, Length: 2159, dtype: float64

# %%
3349 in sp500.values
# Out:
# True

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # PRACTICE OPPORTUNITIES SOLUTIONS

# %% [markdown]
# # PRACTICE OPPORTUNITY #1 SOLUTION:

# %%
# Let's define a Python list that contains 3 top stocks
my_list = ['Facebook','Apple','Nvidia']
my_series = pd.Series(data = my_list)
my_series

# %%
type(my_series)

# %% [markdown]
# # PRACTICE OPPORTUNITY #2 SOLUTION:

# %%
stocks = {'Facebook': 3000,
          'Apple'   : 400,
          'Nvidia'  : 2200}
print(stocks)

# %%
# Let's define a Pandas Series Using the dictionary
my_series = pd.Series(stocks)
my_series

# %% [markdown]
# # PRACTICE OPPORTUNITY #3 SOLUTION:

# %%
crypto_prices.tail(2)

# %%
crypto_prices.memory_usage()

# %% [markdown]
# # PRACTICE OPPORTUNITY #4 SOLUTION:

# %%
my_series = pd.Series(data = [-10, 100, -30, 50, 100])
my_series

# %%
abs(my_series)

# %%
set(my_series)

# %% [markdown]
# # PRACTICE OPPORTUNITY #5 SOLUTION:

# %%
# Obtain the average - Solution #1
BTC_price_series.sum()/BTC_price_series.count()

# %%
# Obtain the average - Solution #s
BTC_price_series.mean()

# %% [markdown]
# # GREAT JOB!
